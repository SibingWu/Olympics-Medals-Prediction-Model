# %% [markdown]
# # Data cleaning of possible predictors of the Olympics throughout the years
# - GDP per capita (number var)
# - Population (number var)
# - Olympic host city (boolean var)
#
# We'll take these information from external data files that we found online.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import relevant data files.
# - CountryCode-to-CountryName conversion .csv file
# - Code Conversion table from ibiblio.org due to difference in code standards of external data files with Olympic dataset.

# %%
noc_dataset = pd.read_csv("data/noc_regions.csv")

conversion_list = pd.read_html("http://www.ibiblio.org/units/codes/country.htm")

#Cleaning the iBiblio html table
conversion_dataset = pd.concat(conversion_list, ignore_index = True)
conversion_dataset = conversion_dataset.rename(columns = conversion_dataset.iloc[0])
conversion_dataset = conversion_dataset.drop(conversion_dataset.index[0])
conversion_dataset = conversion_dataset[conversion_dataset["Country Name"] != "Country Name"]

conversion_dataset = conversion_dataset.rename(columns = {"ISO  3-alpha": "ISO_3A", "IOC  Olympic": "IOC_Olympic"})
conversion_dataset = conversion_dataset.reset_index(drop = True)

conversion_dataset.head()
# Out:
#            Country Name ISO  2-alpha ISO_3A IANA  Internet UN  Vehicle  \
# 0           AFGHANISTAN           AF    AFG            .af         AFG
# 1         ÅLAND ISLANDS           AX    ALA            .ax         NaN
# 2               ALBANIA           AL    ALB            .al          AL
# 3              ALDERNEY          NaN    NaN            NaN         GBA
# 4  ALGERIA (El Djazaïr)           DZ    DZA            .dz          DZ
#
#   IOC_Olympic UN/ISO  numeric ITU  calling
# 0         AFG             004           93
# 1         NaN             248          NaN
# 2         ALB             008          355
# 3         NaN             NaN          NaN
# 4         ALG             012          213

# %% [markdown]
# ## Import external excel or csv files for GDP, population, and host city information. Clean dataset such that it only takes from year 1960 and above.

# %% [markdown]
# ### GDP

# %%
gdp_dataset = pd.read_excel("data/gdp_per_capita.xls")
#Set column names
gdp_dataset.columns = gdp_dataset.iloc[2]

#Delete unnecessary rows and columns
gdp_dataset = gdp_dataset.drop(range(3))
gdp_dataset = gdp_dataset.drop(columns = ["Indicator Name", "Indicator Code", 2017, 2018])

#Reset row numbers; start from 1
gdp_dataset = gdp_dataset.reset_index(drop = True)

gdp_dataset = gdp_dataset.rename(columns = {"Country Name": "CountryName", "Country Code": "CountryCode"})

gdp_dataset
# Out:
# 2                                          CountryName CountryCode  \
# 0                                                Aruba         ABW
# 1                                          Afghanistan         AFG
# 2                                               Angola         AGO
# 3                                              Albania         ALB
# 4                                              Andorra         AND
# 5                                           Arab World         ARB
# 6                                 United Arab Emirates         ARE
# 7                                            Argentina         ARG
# 8                                              Armenia         ARM
# 9                                       American Samoa         ASM
# 10                                 Antigua and Barbuda         ATG
# 11                                           Australia         AUS
# 12                                             Austria         AUT
# 13                                          Azerbaijan         AZE
# 14                                             Burundi         BDI
# 15                                             Belgium         BEL
# 16                                               Benin         BEN
# 17                                        Burkina Faso         BFA
# 18                                          Bangladesh         BGD
# 19                                            Bulgaria         BGR
# 20                                             Bahrain         BHR
# 21                                        Bahamas, The         BHS
# 22                              Bosnia and Herzegovina         BIH
# 23                                             Belarus         BLR
# 24                                              Belize         BLZ
# 25                                             Bermuda         BMU
# 26                                             Bolivia         BOL
# 27                                              Brazil         BRA
# 28                                            Barbados         BRB
# 29                                   Brunei Darussalam         BRN
# ..                                                 ...         ...
# 233  Latin America & the Caribbean (IDA & IBRD coun...         TLA
# 234                                        Timor-Leste         TLS
# 235  Middle East & North Africa (IDA & IBRD countries)         TMN
# 236                                              Tonga         TON
# 237                            South Asia (IDA & IBRD)         TSA
# 238          Sub-Saharan Africa (IDA & IBRD countries)         TSS
# 239                                Trinidad and Tobago         TTO
# 240                                            Tunisia         TUN
# 241                                             Turkey         TUR
# 242                                             Tuvalu         TUV
# 243                                           Tanzania         TZA
# 244                                             Uganda         UGA
# 245                                            Ukraine         UKR
# 246                                Upper middle income         UMC
# 247                                            Uruguay         URY
# 248                                      United States         USA
# 249                                         Uzbekistan         UZB
# 250                     St. Vincent and the Grenadines         VCT
# 251                                      Venezuela, RB         VEN
# 252                             British Virgin Islands         VGB
# 253                              Virgin Islands (U.S.)         VIR
# 254                                            Vietnam         VNM
# 255                                            Vanuatu         VUT
# 256                                              World         WLD
# 257                                              Samoa         WSM
# 258                                             Kosovo         XKX
# 259                                        Yemen, Rep.         YEM
# 260                                       South Africa         ZAF
# 261                                             Zambia         ZMB
# 262                                           Zimbabwe         ZWE
#
# 2         1960.0       1961.0       1962.0       1963.0       1964.0  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1      59.777327    59.878153    58.492874    78.782758    82.208444
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# 5            NaN          NaN          NaN          NaN          NaN
# 6            NaN          NaN          NaN          NaN          NaN
# 7            NaN          NaN  1148.579957   845.077184  1166.317400
# 8            NaN          NaN          NaN          NaN          NaN
# 9            NaN          NaN          NaN          NaN          NaN
# 10           NaN          NaN          NaN          NaN          NaN
# 11   1807.349784  1874.304768  1851.424816  1963.639079  2127.566902
# 12    935.460427  1031.815004  1087.834243  1167.000532  1269.412583
# 13           NaN          NaN          NaN          NaN          NaN
# 14     70.349079    71.487278    73.781765    78.900284    86.603195
# 15   1273.691659  1350.197673  1438.523233  1535.023729  1701.846276
# 16     93.022509    95.572155    94.464535    99.859114   104.339768
# 17     68.424749    71.558180    76.520611    78.372072    80.472767
# 18     88.691211    97.142730    99.576714   101.260491    99.503864
# 19           NaN          NaN          NaN          NaN          NaN
# 20           NaN          NaN          NaN          NaN          NaN
# 21   1550.324315  1651.475477  1752.970293  1867.112988  1994.544920
# 22           NaN          NaN          NaN          NaN          NaN
# 23           NaN          NaN          NaN          NaN          NaN
# 24    304.917107   316.403606   327.126867   336.941466   351.161126
# 25   1902.402119  1961.538169  2020.385965  2020.265248  2199.727007
# 26    101.227704   108.022520   115.855641   122.350540   135.181861
# 27    210.027470   204.929302   260.225266   291.950589   261.331083
# 28           NaN          NaN          NaN          NaN          NaN
# 29           NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 233   364.627854   374.939363   417.369942   408.597891   443.086920
# 234          NaN          NaN          NaN          NaN          NaN
# 235          NaN          NaN          NaN          NaN          NaN
# 236          NaN          NaN          NaN          NaN          NaN
# 237    81.560979    85.203410    89.011798    97.961148   109.756897
# 238   129.952986   131.935170   139.612810   156.241368   148.741801
# 239   631.329859   675.974402   703.753422   759.868843   788.124732
# 240          NaN          NaN          NaN          NaN          NaN
# 241   509.424112   285.012709   309.446903   350.663223   369.583786
# 242          NaN          NaN          NaN          NaN          NaN
# 243          NaN          NaN          NaN          NaN          NaN
# 244    62.315122    63.015161    62.016822    68.935251    76.044610
#Drop unnecessary rows and columns
host_dataset = host_dataset.drop(columns = ["City", "Continent", "Opening Ceremony", "Closing Ceremony"])
host_dataset = host_dataset.drop(list(range(25)) + list(range(58, 64)))

#Year change from float to integer
host_dataset["Year"] = host_dataset["Year"].astype(int)
host_dataset = host_dataset.reset_index(drop = True)

host_dataset.head()
# Out:
#   Code  Country Summer Winter  Year
# 0  USA      USA      -   VIII  1960
# 1  ITA    Italy   XVII      -  1960
# 2  AUT  Austria      -     IX  1964
# 3  JPN    Japan  XVIII      -  1964
# 4  FRA   France      -      X  1968

# %% [markdown]
# ### Population

# %%
pop_dataset = pd.read_csv("data/world_population.csv")

pop_dataset = pd.read_csv("data/world_population.csv")
pop_dataset = pop_dataset.drop(columns = ["Indicator Name", "Indicator Code", "Unnamed: 61"])

pop_dataset = pop_dataset.rename(columns = {"Country": "CountryName", "Country Code": "CountryCode"})

pop_dataset.head()
# Out:
#    CountryName CountryCode       1960       1961       1962       1963  \
# 0        Aruba         ABW    54211.0    55438.0    56225.0    56695.0
# 1  Afghanistan         AFG  8996351.0  9166764.0  9345868.0  9533954.0
# 2       Angola         AGO  5643182.0  5753024.0  5866061.0  5980417.0
# 3      Albania         ALB  1608800.0  1659800.0  1711319.0  1762621.0
# 4      Andorra         AND    13411.0    14375.0    15370.0    16412.0
#
#         1964       1965        1966        1967    ...           2007  \
# 0    57032.0    57360.0     57715.0     58055.0    ...       101220.0
# 1  9731361.0  9938414.0  10152331.0  10372630.0    ...     26616792.0
# 2  6093321.0  6203299.0   6309770.0   6414995.0    ...     20997687.0
# 3  1814135.0  1864791.0   1914573.0   1965598.0    ...      2970017.0
# 4    17469.0    18549.0     19647.0     20758.0    ...        82683.0
#
#          2008        2009        2010        2011        2012        2013  \
# 0    101353.0    101453.0    101669.0    102053.0    102577.0    103187.0
# 1  27294031.0  28004331.0  28803167.0  29708599.0  30696958.0  31731688.0
# 2  21759420.0  22549547.0  23369131.0  24218565.0  25096150.0  25998340.0
# 3   2947314.0   2927519.0   2913021.0   2905195.0   2900401.0   2895092.0
# 4     83861.0     84462.0     84449.0     83751.0     82431.0     80788.0
#
#          2014        2015      2016
# 0    103795.0    104341.0    104822
# 1  32758020.0  33736494.0  34656032
# 2  26920466.0  27859305.0  28813463
# 3   2889104.0   2880703.0   2876101
# 4     79223.0     78014.0     77281
#
# [5 rows x 59 columns]

# %% [markdown]
# ### Do country code conversion for standardization. (ISO 3-alpha to IOC Olympic)

# %%
iso_to_ioc_dataset = conversion_dataset[["ISO_3A", "IOC_Olympic"]]
iso_to_ioc_dataset = iso_to_ioc_dataset.dropna()

gdp_dataset = gdp_dataset.merge(iso_to_ioc_dataset, left_on = "CountryCode", right_on = "ISO_3A")
gdp_dataset["CountryCode"] = gdp_dataset["IOC_Olympic"]
gdp_dataset = gdp_dataset.drop(columns = ["ISO_3A", "IOC_Olympic"])

pop_dataset = pop_dataset.merge(iso_to_ioc_dataset, left_on = "CountryCode", right_on = "ISO_3A")
pop_dataset["CountryCode"] = pop_dataset["IOC_Olympic"]
pop_dataset = pop_dataset.drop(columns = ["ISO_3A", "IOC_Olympic"])

# %% [markdown]
# # GDP per capita in US dollars

# %% [markdown]
# ### Create GDP dataset for summer

# %%
summer_gdp_dataset = gdp_dataset

#Change year number columns from float to integer
#Only need years multiple of 4, drop the other columns
col_list = []
#ignore the first 2 columns, 'Country Name' and 'Country Code'
idx = 2

for col in summer_gdp_dataset.columns:
    if type(col) == np.float64:
        if col % 4 != 0: #year is not a multiple of 4
            summer_gdp_dataset = summer_gdp_dataset.drop(summer_gdp_dataset.columns[idx], axis = 1)
        else:
            col = int(col)
            idx += 1
            col_list.append(col)
    else:
        col_list.append(col)
summer_gdp_dataset.columns = col_list

#2 decimal places
summer_gdp_dataset.round(2).head()
# Out:
#    CountryName CountryCode   1960   1964    1968     1972     1976      1980  \
# 0        Aruba         ARU    NaN    NaN     NaN      NaN      NaN       NaN
# 1  Afghanistan         AFG  59.78  82.21  129.51   136.12   199.03    274.88
# 2       Angola         ANG    NaN    NaN     NaN      NaN      NaN    664.12
# 3      Albania         ALB    NaN    NaN     NaN      NaN      NaN       NaN
# 4      Andorra         AND    NaN    NaN     NaN  4217.17  7152.38  12377.41
#
#       1984      1988      1992      1996      2000      2004      2008  \
# 0      NaN   9764.79  14046.50  16586.07  20620.70  22569.97  27086.04
# 1      NaN       NaN       NaN       NaN       NaN    216.71    370.38
# 2   596.60    761.62    640.62    512.62    555.30   1248.40   4068.98
# 3   639.48    652.77    200.85   1009.98   1126.68   2373.58   4370.54
# 4  7728.91  14304.36  20547.71  19017.17  21936.53  38503.48  47785.66
#
#        2012      2016
# 0  24709.60  25251.64
# 1    648.51    549.58
# 2   5102.49   3509.60
# 3   4247.61   4131.87
# 4  38391.08  37231.82

# %% [markdown]
# ### Create GDP dataset for Winter
# After 1992, the Winter Olympics start playing in alternate years with the Summer Olympics.

# %%
winter_gdp_dataset = gdp_dataset

#Change year number columns from float to integer
#Only need years multiple of 4, drop the other columns
col_list = []
#ignore the first 2 columns, 'Country Name' and 'Country Code'
idx = 2 

for col in winter_gdp_dataset.columns:
    if type(col) == np.float64:
        if col <= 1992:
            if col % 4 != 0: 
                winter_gdp_dataset = winter_gdp_dataset.drop(winter_gdp_dataset.columns[idx], axis = 1)
            else:
                col = int(col)
                idx += 1
                col_list.append(col)
        else:
            if (col+2) % 4 != 0:
                winter_gdp_dataset = winter_gdp_dataset.drop(winter_gdp_dataset.columns[idx], axis = 1)
            else:
                col = int(col)
                idx += 1
                col_list.append(col)
    else:
        col_list.append(col)
        
winter_gdp_dataset.columns = col_list
#2 decimal places
winter_gdp_dataset.round(2).head()
# Out:
#    CountryName CountryCode   1960   1964    1968     1972     1976      1980  \
# 0        Aruba         ARU    NaN    NaN     NaN      NaN      NaN       NaN
# 1  Afghanistan         AFG  59.78  82.21  129.51   136.12   199.03    274.88
# 2       Angola         ANG    NaN    NaN     NaN      NaN      NaN    664.12
# 3      Albania         ALB    NaN    NaN     NaN      NaN      NaN       NaN
# 4      Andorra         AND    NaN    NaN     NaN  4217.17  7152.38  12377.41
#
#       1984      1988      1992      1994      1998      2002      2006  \
# 0      NaN   9764.79  14046.50  16241.05  19078.34  20436.89  24045.75
# 1      NaN       NaN       NaN       NaN       NaN    184.49    269.23
# 2   596.60    761.62    640.62    320.66    419.64    869.85   2585.13
# 3   639.48    652.77    200.85    586.42    813.79   1425.12   2972.74
# 4  7728.91  14304.36  20547.71  16234.81  18894.52  24741.49  43748.77
#
#        2010      2014
# 0  23512.60  25528.40
# 1    550.51    625.34
# 2   3585.91   5412.69
# 3   4094.36   4578.67
# 4  39736.35  42294.99

# %% [markdown]
# # Olympic host cities

# %% [markdown]
# ### Create host city dataset for summer

# %%
summer_host_dataset = host_dataset[host_dataset.Summer != '-']

summer_host_dataset = summer_host_dataset.reset_index(drop = True)
summer_host_dataset = summer_host_dataset.drop(columns = ["Summer", "Winter"])
summer_host_dataset = summer_host_dataset.rename(columns = {"Country": "CountryName", "Code": "CountryCode"})

summer_host_dataset
# Out:
#    CountryCode     CountryName  Year
# 0          ITA           Italy  1960
# 1          JPN           Japan  1964
# 2          MEX          Mexico  1968
# 3          GER    West Germany  1972
# 4          CAN          Canada  1976
# 5          RUS    Soviet Union  1980
# 6          USA             USA  1984
# 7          KOR     South Korea  1988
# 8          ESP           Spain  1992
# 9          USA             USA  1996
# 10         AUS       Australia  2000
# 11         GRE          Greece  2004
# 12         CHN           China  2008
# 13         GBR  United Kingdom  2012
# 14         BRA          Brazil  2016
# 15         JPN           Japan  2020

# %% [markdown]
# ### Create host city dataset for winter

# %%
winter_host_dataset = host_dataset[host_dataset.Winter != '-']
winter_host_dataset = winter_host_dataset.reset_index(drop = True)
winter_host_dataset = winter_host_dataset.drop(columns = ["Summer", "Winter"])
winter_host_dataset = winter_host_dataset.rename(columns = {"Country": "CountryName", "Code": "CountryCode"})

winter_host_dataset
# Out:
#    CountryCode  CountryName  Year
# 0          USA          USA  1960
# 1          AUT      Austria  1964
# 2          FRA       France  1968
# 3          JPN        Japan  1972
# 4          AUT      Austria  1976
# 5          USA          USA  1980
# 6          SRB   Yugoslavia  1984
# 7          CAN       Canada  1988
# 8          FRA       France  1992
# 9          NOR       Norway  1994
# 10         JPN        Japan  1998
# 11         USA          USA  2002
# 12         ITA        Italy  2006
# 13         CAN       Canada  2010
# 14         RUS       Russia  2014
# 15         KOR  South Korea  2018
# 16         CHN        China  2022

# %% [markdown]
# #### Summer

# %%
summer_pop_dataset = pop_dataset
col_list = []
idx = 2

for col in summer_pop_dataset.columns:
    if col.isdigit():
        col = int(col)
        if col % 4 != 0: #year is not a multiple of 4
            summer_pop_dataset = summer_pop_dataset.drop(summer_pop_dataset.columns[idx], axis = 1)
        else:
            idx += 1

summer_pop_dataset.head()
# Out:
#    CountryName CountryCode       1960       1964        1968        1972  \
# 0        Aruba         ARU    54211.0    57032.0     58386.0     59840.0
# 1  Afghanistan         AFG  8996351.0  9731361.0  10604346.0  11721940.0
# 2       Angola         ANG  5643182.0  6093321.0   6523791.0   7094834.0
# 3      Albania         ALB  1608800.0  1814135.0   2022272.0   2243126.0
# 4      Andorra         AND    13411.0    17469.0     21890.0     26892.0
#
#          1976        1980        1984        1988        1992        1996  \
# 0     60586.0     60096.0     62836.0     61079.0     68235.0     83200.0
# 1  12840299.0  13248370.0  12047115.0  11540888.0  13981231.0  17822884.0
# 2   7900997.0   8929900.0  10277321.0  11513968.0  12968345.0  14682284.0
# 3   2458526.0   2671997.0   2904429.0   3142336.0   3247039.0   3168033.0
# 4     31777.0     36067.0     42706.0     50434.0     58888.0     64360.0
#
#        2000        2004        2008        2012      2016
# 0     90853     98737.0    101353.0    102577.0    104822
# 1  20093756  24118979.0  27294031.0  30696958.0  34656032
# 2  16440924  18865716.0  21759420.0  25096150.0  28813463
# 3   3089027   3026939.0   2947314.0   2900401.0   2876101
# 4     65390     76244.0     83861.0     82431.0     77281

# %% [markdown]
# #### Winter

# %%
winter_pop_dataset = pop_dataset
col_list = []
idx = 2

for col in winter_pop_dataset.columns:
    if col.isdigit():
        col = int(col)
        
        if col <= 1992:
            if col % 4 != 0: #year is not a multiple of 4
                winter_pop_dataset = winter_pop_dataset.drop(winter_pop_dataset.columns[idx], axis = 1)
            else:
                idx += 1
                
        else:
            if (col+2) % 4 != 0:
                winter_pop_dataset = winter_pop_dataset.drop(winter_pop_dataset.columns[idx], axis = 1)
            else:
                idx += 1

winter_pop_dataset.head()
# Out:
#    CountryName CountryCode       1960       1964        1968        1972  \
# 0        Aruba         ARU    54211.0    57032.0     58386.0     59840.0
# 1  Afghanistan         AFG  8996351.0  9731361.0  10604346.0  11721940.0
# 2       Angola         ANG  5643182.0  6093321.0   6523791.0   7094834.0
# 3      Albania         ALB  1608800.0  1814135.0   2022272.0   2243126.0
# 4      Andorra         AND    13411.0    17469.0     21890.0     26892.0
#
#          1976        1980        1984        1988        1992        1994  \
# 0     60586.0     60096.0     62836.0     61079.0     68235.0     76700.0
# 1  12840299.0  13248370.0  12047115.0  11540888.0  13981231.0  16172719.0
# 2   7900997.0   8929900.0  10277321.0  11513968.0  12968345.0  13841301.0
# 3   2458526.0   2671997.0   2904429.0   3142336.0   3247039.0   3207536.0
# 4     31777.0     36067.0     42706.0     50434.0     58888.0     62677.0
#
#        1998        2002        2006        2010        2014
# 0     87277     94992.0    100832.0    101669.0    103795.0
# 1  18863999  21979923.0  25893450.0  28803167.0  32758020.0
# 2  15504318  17572649.0  20262399.0  23369131.0  26920466.0
# 3   3128530   3051010.0   2992547.0   2913021.0   2889104.0
# 4     64142     70049.0     80991.0     84449.0     79223.0

# %% [markdown]
# ### Transfer to .csv files

# %%
summer_pop_dataset.to_csv("predictordata/summer_pop_dataset.csv")
summer_host_dataset.to_csv("predictordata/summer_host_dataset.csv")
summer_gdp_dataset.to_csv("predictordata/summer_gdp_dataset.csv")
winter_pop_dataset.to_csv("predictordata/winter_pop_dataset.csv")
winter_host_dataset.to_csv("predictordata/winter_host_dataset.csv")
winter_gdp_dataset.to_csv("predictordata/winter_gdp_dataset.csv")
